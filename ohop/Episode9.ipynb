# %%
import nbimport

# %%
import Episode8
# Out:
# ERROR:root:Exception in cell.
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/ohop/nbimport.py", line 73, in load_module
#     exec(code, manager.namespace)
#   File "<string>", line 1, in <module>
#   File "<string>", line 1
#     the_possibly_worst_answer = 0
#                               ^
# SyntaxError: invalid syntax
# ERROR:root:Exception in cell.
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/ohop/nbimport.py", line 73, in load_module
#     exec(code, manager.namespace)
#   File "<string>", line 2, in <module>
#   File "<string>", line 1
#     not_a_good_answer = -1
#                       ^
# SyntaxError: invalid syntax
# ERROR:root:Exception in cell.
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/ohop/nbimport.py", line 73, in load_module
#     exec(code, manager.namespace)
#   File "<string>", line 1, in <module>
# NameError: name '_13' is not defined
# ERROR:root:Exception in cell.
# ...

# %%
# %%script sh --no-raise-error
# cd ..
# python -m exercises.exercise1
# Out:
# ..FFF
# ...
# FAIL: test_constant_fold_2 (__main__.TestSolution1)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 32, in test_constant_fold_2
#     self._run_test_case(2)
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 20, in _run_test_case
#     self.assertEqual(
# AssertionError: "Modu[74 chars]left=BinOp(\n                    left=BinOp(\n[312 chars]=[])" != "Modu[74 chars]left=Constant(value=10),\n                op=A[79 chars]=[])"
# Diff is 645 characters long. Set self.maxDiff to None to see it.
#
# ...
# FAIL: test_constant_fold_3 (__main__.TestSolution1)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 35, in test_constant_fold_3
#     self._run_test_case(3)
# ...

# %%
# %%script sh --no-raise-error
# cd ..
# python -m exercises.exercise1
# Out:
# ...EF
# ...
# ERROR: test_constant_fold_3 (__main__.TestSolution1)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 35, in test_constant_fold_3
#     self._run_test_case(3)
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 19, in _run_test_case
#     result = ast.fix_missing_locations(transformer.visit(ast.parse(input_str)))
#   File "/Users/jon/miniforge3/envs/ohop/lib/python3.9/ast.py", line 407, in visit
#     return visitor(node)
#   File "/Users/jon/miniforge3/envs/ohop/lib/python3.9/ast.py", line 483, in generic_visit
#     value = self.visit(value)
#   File "/Users/jon/miniforge3/envs/ohop/lib/python3.9/ast.py", line 407, in visit
#     return visitor(node)
#   File "/Users/jon/miniforge3/envs/ohop/lib/python3.9/ast.py", line 492, in generic_visit
#     new_node = self.visit(old_value)
# ...

# %%
# %%script sh --no-raise-error
# cd ..
# python -m exercises.exercise1
# Out:
# ...FF
# ...
# FAIL: test_constant_fold_3 (__main__.TestSolution1)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 35, in test_constant_fold_3
#     self._run_test_case(3)
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 20, in _run_test_case
#     self.assertEqual(
# AssertionError: "Modu[74 chars]left=Constant(value='34'),\n                op[72 chars]=[])" != "Modu[74 chars]left=BinOp(\n                    left=Constant[192 chars]=[])"
#   Module(
#       body=[
#           Expr(
#               value=BinOp(
# +                 left=BinOp(
# -                 left=Constant(value='34'),
# ?                                     - --
# +                     left=Constant(value=3),
# ? ++++
# +                     op=Add(),
# +                     right=Name(id='frotz', ctx=Load())),
#                   op=Add(),
# ...

# %%
import sys
sys.path.append('..')
from exercises.exercise1 import TestSolution1

# %%
import ast
from exercises.solutions.solution1 import Episode9Solution
Solution = Episode9Solution
def _run_test_case(index):
    input_str, output_str = TestSolution1.test_cases[index]
    transformer = Solution()
    result = ast.fix_missing_locations(transformer.visit(ast.parse(input_str)))
    return (
        ast.dump(result, indent=4),
        ast.dump(ast.parse(output_str), indent=4)
    )
tc_result, tc_expected = _run_test_case(3)

# %%
print(tc_result)
print(tc_expected)
# Out:
# Module(
#     body=[
#         Expr(
#             value=BinOp(
#                 left=Constant(value='34'),
#                 op=Add(),
#                 right=Constant(value='3')))],
#     type_ignores=[])
# Module(
#     body=[
#         Expr(
#             value=BinOp(
#                 left=BinOp(
#                     left=Constant(value=3),
#                     op=Add(),
#                     right=Name(id='frotz', ctx=Load())),
#                 op=Add(),
#                 right=Constant(value='34')))],
#     type_ignores=[])

# %%
# %%script sh --no-raise-error
# cd ..
# python -m exercises.exercise1
# Out:
# ...FF
# ...
# FAIL: test_constant_fold_3 (__main__.TestSolution1)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 35, in test_constant_fold_3
#     self._run_test_case(3)
#   File "/Users/jon/git/ohop/exercises/exercise1.py", line 20, in _run_test_case
#     self.assertEqual(
# AssertionError: "Modu[74 chars]left=Constant(value='34'),\n                op[192 chars]=[])" != "Modu[74 chars]left=BinOp(\n                    left=Constant[192 chars]=[])"
#   Module(
#       body=[
#           Expr(
#               value=BinOp(
# -                 left=Constant(value='34'),
# -                 op=Add(),
# -                 right=BinOp(
# ?                 ^^^^
# +                 left=BinOp(
# ?                 ^^^
#                       left=Constant(value=3),
#                       op=Add(),
# -                     right=Name(id='frotz', ctx=Load()))))],
# ...
